# %%
from astropy.io import fits

# %%
hdu = fits.open('slit.M32RA1.018B.fits.gz')
print(hdu.info())
print(hdu[2].header.keys)
data = hdu[2].header.keys
#print(data['R1'],data['R2'],data['R1'],data['R2'])
# Out:
# Filename: slit.M32RA1.018B.fits.gz
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  slit          1 BinTableHDU    109   1R x 11C   [204800E, 204800E, 204800B, 204800B, 4096E, 204800E, 6D, 5D, 50E, 150D, 204800J]
#   2  slit          1 BinTableHDU    101   450R x 5C   [E, E, E, E, B]
# None
# <bound method Header.keys of XTENSION= 'BINTABLE'           /Binary table written by MWRFITS v1.4
# BITPIX  =                    8 /Required value
# NAXIS   =                    2 /Required value
# NAXIS1  =                   17 /Number of bytes per row
# NAXIS2  =                  450 /Number of rows
# PCOUNT  =                    0 /Normally 0 (no varying arrays)
# GCOUNT  =                    1 /Required value
# TFIELDS =                    5 /Number of columns in table
# COMMENT
# COMMENT  *** End of mandatory fields ***
# COMMENT
# COMMENT
# COMMENT  *** Column names ***
# COMMENT
# TTYPE1  = 'AMP     '           /
# ...
